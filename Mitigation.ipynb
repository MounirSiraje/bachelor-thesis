# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline
import xgboost as xgb
import pandas as pd
import numpy as np

# === Load the transformed dataset ===
file_path = "vroegtijdig-schoolverlaten-woonplaats-dataset-2022-2023.xlsx"
bad_df = pd.read_excel(file_path)

def transform_dataset(bad_df):
    transformed_rows = []
    for _, row in bad_df.iterrows():
        vsv_noemer = row['vsv_noemer']
        vsv_teller = row['vsv_teller']
        for i in range(vsv_noemer):
            new_row = row.copy()
            new_row['vsv_teller'] = 1 if i < vsv_teller else 0
            transformed_rows.append(new_row)
    df = pd.DataFrame(transformed_rows)
    df = df.drop(columns=['vsv_noemer'])
    return df

df = transform_dataset(bad_df)

# Drop unnecessary column
if 'schooljaar' in df.columns:
    df.drop(columns=['schooljaar'], inplace=True)

# Separate features and target
X = df.drop(columns=['vsv_teller'])
y = df['vsv_teller']

# Stratified train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42
)

# Define columns
categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(include=['number']).columns

# Define preprocessor
categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

preprocessor = ColumnTransformer([
    ('cat', categorical_transformer, categorical_cols)
], remainder='passthrough')

# Define resampling steps
over = SMOTE(sampling_strategy=0.5, random_state=42)
under = RandomUnderSampler(sampling_strategy=0.8, random_state=42)

# Define models
rf = RandomForestClassifier(class_weight='balanced', random_state=42)
logreg = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)
xgb_model = xgb.XGBClassifier(scale_pos_weight=3, use_label_encoder=False, eval_metric='logloss')

# Pipelines
models = {
    "Baseline_RF": Pipeline([('preprocess', preprocessor), ('clf', rf)]),
    "BiasMitigated_RF": ImbPipeline([('preprocess', preprocessor), ('over', over), ('under', under), ('clf', rf)]),
    "BiasMitigated_LogReg": ImbPipeline([('preprocess', preprocessor), ('over', over), ('under', under), ('clf', logreg)]),
    "BiasMitigated_XGBoost": Pipeline([('preprocess', preprocessor), ('clf', xgb_model)]),
}

# Evaluate all models
def evaluate_all_models(models, X_train, X_test, y_train, y_test):
    results = {}
    for name, pipeline in models.items():
        print(f"\n📦 Training model: {name}")
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)
        y_proba = pipeline.predict_proba(X_test)[:, 1] if hasattr(pipeline, "predict_proba") else None

        acc = np.mean(y_pred == y_test)
        auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
        report = classification_report(y_test, y_pred, output_dict=True)

        results[name] = {
            'model': pipeline,
            'y_pred': y_pred,
            'y_proba': y_proba,
            'accuracy': acc,
            'roc_auc': auc,
            'report': report
        }

        print(f"→ Accuracy: {acc:.4f}")
        if auc:
            print(f"→ ROC AUC: {auc:.4f}")
        print(classification_report(y_test, y_pred))
    return results

model_results = evaluate_all_models(models, X_train, X_test, y_train, y_test)
# Out:
# 📦 Training model: Baseline_RF
# → Accuracy: 0.9468
# → ROC AUC: 0.9303
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     12444
#            1       0.85      0.73      0.78      1890
#
#     accuracy                           0.95     14334
#    macro avg       0.90      0.85      0.88     14334
# weighted avg       0.94      0.95      0.95     14334
#
#
# 📦 Training model: BiasMitigated_RF
# → Accuracy: 0.9436
# → ROC AUC: 0.9361
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     12444
#            1       0.81      0.75      0.78      1890
#
#     accuracy                           0.94     14334
#    macro avg       0.88      0.86      0.87     14334
# weighted avg       0.94      0.94      0.94     14334
#
#
# 📦 Training model: BiasMitigated_LogReg
# → Accuracy: 0.9103
# → ROC AUC: 0.9400
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95     12444
#            1       0.62      0.83      0.71      1890
#
#     accuracy                           0.91     14334
#    macro avg       0.80      0.88      0.83     14334
# weighted avg       0.93      0.91      0.92     14334
#
#
# 📦 Training model: BiasMitigated_XGBoost
# C:\Users\mouni\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:45:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# → Accuracy: 0.9419
# → ROC AUC: 0.9450
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     12444
#            1       0.78      0.78      0.78      1890
#
#     accuracy                           0.94     14334
#    macro avg       0.87      0.87      0.87     14334
# weighted avg       0.94      0.94      0.94     14334

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

protected_attrs = ['geslacht', 'belg_nietbelg', 'eu_nieteu', 'woonplaats_provincie_naam', 'leeftijdscategorie', 'opleidingsniveau_moeder', 'schoolse_vordering']

def fairness_analysis(X_test, y_test, y_pred, protected_features):
    X_test_copy = X_test.copy()
    X_test_copy['true'] = y_test.values
    X_test_copy['pred'] = y_pred

    for feature in protected_features:
        print(f"\n Fairness Analysis by: {feature}")
        for group in X_test_copy[feature].unique():
            subset = X_test_copy[X_test_copy[feature] == group]
            if subset.shape[0] < 10:
                print(f"  Skipping group '{group}' due to too few samples.")
                continue

            y_true = subset['true']
            y_group_pred = subset['pred']

            tn, fp, fn, tp = confusion_matrix(y_true, y_group_pred).ravel()
            precision = precision_score(y_true, y_group_pred, zero_division=0)
            recall = recall_score(y_true, y_group_pred, zero_division=0)
            f1 = f1_score(y_true, y_group_pred, zero_division=0)
            fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
            fnr = fn / (fn + tp) if (fn + tp) > 0 else 0

            print(f"  Group '{group}' (n={len(subset)}):")
            print(f"    TP={tp}, FP={fp}, FN={fn}, TN={tn}")
            print(f"    Precision: {precision:.3f} | Recall: {recall:.3f} | F1: {f1:.3f}")
            print(f"    FPR: {fpr:.3f} | FNR: {fnr:.3f}")

def compare_fairness(model_results, X_test, y_test, protected_attrs):
    for model_name, data in model_results.items():
        print(f"\n=== Fairness Evaluation for: {model_name} ===")
        y_pred = data['y_pred']
        fairness_analysis(X_test, y_test, y_pred, protected_attrs)

# %%
compare_fairness(model_results, X_test, y_test, protected_attrs)
# Out:
# === Fairness Evaluation for: Baseline_RF ===
#
#  Fairness Analysis by: geslacht
#   Group 'Vrouwelijk' (n=6900):
#     TP=487, FP=89, FN=203, TN=6121
#     Precision: 0.845 | Recall: 0.706 | F1: 0.769
#     FPR: 0.014 | FNR: 0.294
#   Group 'Mannelijk' (n=7434):
#     TP=885, FP=155, FN=315, TN=6079
#     Precision: 0.851 | Recall: 0.738 | F1: 0.790
#     FPR: 0.025 | FNR: 0.263
#
#  Fairness Analysis by: belg_nietbelg
#   Group 'Belg' (n=13089):
#     TP=1046, FP=198, FN=431, TN=11414
#     Precision: 0.841 | Recall: 0.708 | F1: 0.769
#     FPR: 0.017 | FNR: 0.292
#   Group 'niet-Belg' (n=1245):
#     TP=326, FP=46, FN=87, TN=786
#     Precision: 0.876 | Recall: 0.789 | F1: 0.831
#     FPR: 0.055 | FNR: 0.211
#
#  Fairness Analysis by: eu_nieteu
#   Group 'EU' (n=13807):
#     TP=1197, FP=223, FN=470, TN=11917
#     Precision: 0.843 | Recall: 0.718 | F1: 0.776
#     FPR: 0.018 | FNR: 0.282
#   Group 'niet-EU' (n=527):
#     TP=175, FP=21, FN=48, TN=283
#     Precision: 0.893 | Recall: 0.785 | F1: 0.835
#     FPR: 0.069 | FNR: 0.215
#
#  Fairness Analysis by: woonplaats_provincie_naam
#   Group 'Vlaams-Brabant' (n=2205):
#     TP=176, FP=17, FN=61, TN=1951
#     Precision: 0.912 | Recall: 0.743 | F1: 0.819
#     FPR: 0.009 | FNR: 0.257
#   Group 'Oost-Vlaanderen' (n=3319):
#     TP=297, FP=61, FN=116, TN=2845
#     Precision: 0.830 | Recall: 0.719 | F1: 0.770
#     FPR: 0.021 | FNR: 0.281
#   Group 'West-Vlaanderen' (n=2365):
#     TP=173, FP=35, FN=76, TN=2081
#     Precision: 0.832 | Recall: 0.695 | F1: 0.757
#     FPR: 0.017 | FNR: 0.305
#   Group 'Antwerpen' (n=3955):
#     TP=479, FP=94, FN=166, TN=3216
#     Precision: 0.836 | Recall: 0.743 | F1: 0.787
#     FPR: 0.028 | FNR: 0.257
#   Group 'Limburg' (n=1810):
#     TP=165, FP=28, FN=73, TN=1544
#     Precision: 0.855 | Recall: 0.693 | F1: 0.766
#     FPR: 0.018 | FNR: 0.307
#   Group 'Brussels Hoofdstedelijk Gewest' (n=446):
#     TP=70, FP=7, FN=18, TN=351
#     Precision: 0.909 | Recall: 0.795 | F1: 0.848
#     FPR: 0.020 | FNR: 0.205
#   Group 'Buitenland + Waals Gewest' (n=234):
#     TP=12, FP=2, FN=8, TN=212
#     Precision: 0.857 | Recall: 0.600 | F1: 0.706
#     FPR: 0.009 | FNR: 0.400
#
#  Fairness Analysis by: leeftijdscategorie
#   Group '17-18' (n=9902):
#     TP=927, FP=116, FN=157, TN=8702
#     Precision: 0.889 | Recall: 0.855 | F1: 0.872
#     FPR: 0.013 | FNR: 0.145
#   Group '18-19' (n=3187):
#     TP=312, FP=83, FN=216, TN=2576
#     Precision: 0.790 | Recall: 0.591 | F1: 0.676
#     FPR: 0.031 | FNR: 0.409
#   Group '<17-18' (n=265):
#     TP=41, FP=1, FN=3, TN=220
#     Precision: 0.976 | Recall: 0.932 | F1: 0.953
#     FPR: 0.005 | FNR: 0.068
#   Group '20-21' (n=201):
#     TP=16, FP=7, FN=32, TN=146
#     Precision: 0.696 | Recall: 0.333 | F1: 0.451
#     FPR: 0.046 | FNR: 0.667
#   Group '19-20' (n=729):
#     TP=67, FP=29, FN=97, TN=536
#     Precision: 0.698 | Recall: 0.409 | F1: 0.515
#     FPR: 0.051 | FNR: 0.591
#   Group '21-22' (n=36):
#     TP=5, FP=6, FN=7, TN=18
#     Precision: 0.455 | Recall: 0.417 | F1: 0.435
#     FPR: 0.250 | FNR: 0.583
#   Group '>21-22' (n=14):
#     TP=4, FP=2, FN=6, TN=2
#     Precision: 0.667 | Recall: 0.400 | F1: 0.500
#     FPR: 0.500 | FNR: 0.600
#
#  Fairness Analysis by: opleidingsniveau_moeder
#   Group 'Hoger onderwijs' (n=6031):
#     TP=203, FP=32, FN=94, TN=5702
#     Precision: 0.864 | Recall: 0.684 | F1: 0.763
#     FPR: 0.006 | FNR: 0.316
#   Group 'Lager secundair onderwijs' (n=1699):
#     TP=306, FP=38, FN=89, TN=1266
#     Precision: 0.890 | Recall: 0.775 | F1: 0.828
#     FPR: 0.029 | FNR: 0.225
#   Group 'n.v.t.' (n=463):
#     TP=130, FP=72, FN=46, TN=215
#     Precision: 0.644 | Recall: 0.739 | F1: 0.688
#     FPR: 0.251 | FNR: 0.261
#   Group 'Hoger secundair onderwijs' (n=4628):
#     TP=383, FP=58, FN=178, TN=4009
#     Precision: 0.868 | Recall: 0.683 | F1: 0.764
#     FPR: 0.014 | FNR: 0.317
#   Group 'Geen lager onderwijs' (n=596):
#     TP=145, FP=23, FN=45, TN=383
#     Precision: 0.863 | Recall: 0.763 | F1: 0.810
#     FPR: 0.057 | FNR: 0.237
#   Group 'Lager onderwijs' (n=771):
#     TP=168, FP=12, FN=56, TN=535
#     Precision: 0.933 | Recall: 0.750 | F1: 0.832
#     FPR: 0.022 | FNR: 0.250
#   Group 'Onbekend' (n=146):
#     TP=37, FP=9, FN=10, TN=90
#     Precision: 0.804 | Recall: 0.787 | F1: 0.796
#     FPR: 0.091 | FNR: 0.213
#
#  Fairness Analysis by: schoolse_vordering
#   Group 'Geen schoolse achterstand' (n=8940):
#     TP=21, FP=29, FN=122, TN=8768
#     Precision: 0.420 | Recall: 0.147 | F1: 0.218
#     FPR: 0.003 | FNR: 0.853
#   Group 'n.v.t.' (n=914):
#     TP=309, FP=178, FN=115, TN=312
#     Precision: 0.634 | Recall: 0.729 | F1: 0.678
#     FPR: 0.363 | FNR: 0.271
#   Group '1 jaar schoolse achterstand' (n=3186):
#     TP=472, FP=26, FN=186, TN=2502
#     Precision: 0.948 | Recall: 0.717 | F1: 0.817
#     FPR: 0.010 | FNR: 0.283
#   Group 'Meer dan 2 jaar schoolse achterstand' (n=307):
#     TP=166, FP=3, FN=24, TN=114
#     Precision: 0.982 | Recall: 0.874 | F1: 0.925
#     FPR: 0.026 | FNR: 0.126
#   Group '2 jaar schoolse achterstand' (n=987):
#     TP=404, FP=8, FN=71, TN=504
#     Precision: 0.981 | Recall: 0.851 | F1: 0.911
#     FPR: 0.016 | FNR: 0.149
#
# === Fairness Evaluation for: BiasMitigated_RF ===
#
#  Fairness Analysis by: geslacht
#   Group 'Vrouwelijk' (n=6900):
#     TP=506, FP=128, FN=184, TN=6082
#     Precision: 0.798 | Recall: 0.733 | F1: 0.764
#     FPR: 0.021 | FNR: 0.267
#   Group 'Mannelijk' (n=7434):
#     TP=914, FP=211, FN=286, TN=6023
#     Precision: 0.812 | Recall: 0.762 | F1: 0.786
#     FPR: 0.034 | FNR: 0.238
#
#  Fairness Analysis by: belg_nietbelg
#   Group 'Belg' (n=13089):
#     TP=1084, FP=261, FN=393, TN=11351
#     Precision: 0.806 | Recall: 0.734 | F1: 0.768
#     FPR: 0.022 | FNR: 0.266
#   Group 'niet-Belg' (n=1245):
#     TP=336, FP=78, FN=77, TN=754
#     Precision: 0.812 | Recall: 0.814 | F1: 0.813
#     FPR: 0.094 | FNR: 0.186
#
#  Fairness Analysis by: eu_nieteu
#   Group 'EU' (n=13807):
#     TP=1236, FP=299, FN=431, TN=11841
#     Precision: 0.805 | Recall: 0.741 | F1: 0.772
#     FPR: 0.025 | FNR: 0.259
#   Group 'niet-EU' (n=527):
#     TP=184, FP=40, FN=39, TN=264
#     Precision: 0.821 | Recall: 0.825 | F1: 0.823
#     FPR: 0.132 | FNR: 0.175
#
#  Fairness Analysis by: woonplaats_provincie_naam
#   Group 'Vlaams-Brabant' (n=2205):
#     TP=179, FP=23, FN=58, TN=1945
#     Precision: 0.886 | Recall: 0.755 | F1: 0.815
#     FPR: 0.012 | FNR: 0.245
#   Group 'Oost-Vlaanderen' (n=3319):
#     TP=306, FP=85, FN=107, TN=2821
#     Precision: 0.783 | Recall: 0.741 | F1: 0.761
#     FPR: 0.029 | FNR: 0.259
#   Group 'West-Vlaanderen' (n=2365):
#     TP=187, FP=50, FN=62, TN=2066
#     Precision: 0.789 | Recall: 0.751 | F1: 0.770
#     FPR: 0.024 | FNR: 0.249
#   Group 'Antwerpen' (n=3955):
#     TP=486, FP=124, FN=159, TN=3186
#     Precision: 0.797 | Recall: 0.753 | F1: 0.775
#     FPR: 0.037 | FNR: 0.247
#   Group 'Limburg' (n=1810):
#     TP=176, FP=38, FN=62, TN=1534
#     Precision: 0.822 | Recall: 0.739 | F1: 0.779
#     FPR: 0.024 | FNR: 0.261
#   Group 'Brussels Hoofdstedelijk Gewest' (n=446):
#     TP=71, FP=14, FN=17, TN=344
#     Precision: 0.835 | Recall: 0.807 | F1: 0.821
#     FPR: 0.039 | FNR: 0.193
#   Group 'Buitenland + Waals Gewest' (n=234):
#     TP=15, FP=5, FN=5, TN=209
#     Precision: 0.750 | Recall: 0.750 | F1: 0.750
#     FPR: 0.023 | FNR: 0.250
#
#  Fairness Analysis by: leeftijdscategorie
#   Group '17-18' (n=9902):
#     TP=937, FP=146, FN=147, TN=8672
#     Precision: 0.865 | Recall: 0.864 | F1: 0.865
#     FPR: 0.017 | FNR: 0.136
#   Group '18-19' (n=3187):
#     TP=329, FP=106, FN=199, TN=2553
#     Precision: 0.756 | Recall: 0.623 | F1: 0.683
#     FPR: 0.040 | FNR: 0.377
#   Group '<17-18' (n=265):
#     TP=41, FP=6, FN=3, TN=215
#     Precision: 0.872 | Recall: 0.932 | F1: 0.901
#     FPR: 0.027 | FNR: 0.068
#   Group '20-21' (n=201):
#     TP=23, FP=24, FN=25, TN=129
#     Precision: 0.489 | Recall: 0.479 | F1: 0.484
#     FPR: 0.157 | FNR: 0.521
#   Group '19-20' (n=729):
#     TP=79, FP=47, FN=85, TN=518
#     Precision: 0.627 | Recall: 0.482 | F1: 0.545
#     FPR: 0.083 | FNR: 0.518
#   Group '21-22' (n=36):
#     TP=6, FP=8, FN=6, TN=16
#     Precision: 0.429 | Recall: 0.500 | F1: 0.462
#     FPR: 0.333 | FNR: 0.500
#   Group '>21-22' (n=14):
#     TP=5, FP=2, FN=5, TN=2
#     Precision: 0.714 | Recall: 0.500 | F1: 0.588
#     FPR: 0.500 | FNR: 0.500
#
#  Fairness Analysis by: opleidingsniveau_moeder
#   Group 'Hoger onderwijs' (n=6031):
#     TP=207, FP=38, FN=90, TN=5696
#     Precision: 0.845 | Recall: 0.697 | F1: 0.764
#     FPR: 0.007 | FNR: 0.303
#   Group 'Lager secundair onderwijs' (n=1699):
#     TP=315, FP=55, FN=80, TN=1249
#     Precision: 0.851 | Recall: 0.797 | F1: 0.824
#     FPR: 0.042 | FNR: 0.203
#   Group 'n.v.t.' (n=463):
#     TP=138, FP=96, FN=38, TN=191
#     Precision: 0.590 | Recall: 0.784 | F1: 0.673
#     FPR: 0.334 | FNR: 0.216
#   Group 'Hoger secundair onderwijs' (n=4628):
#     TP=396, FP=81, FN=165, TN=3986
#     Precision: 0.830 | Recall: 0.706 | F1: 0.763
#     FPR: 0.020 | FNR: 0.294
#   Group 'Geen lager onderwijs' (n=596):
#     TP=151, FP=30, FN=39, TN=376
#     Precision: 0.834 | Recall: 0.795 | F1: 0.814
#     FPR: 0.074 | FNR: 0.205
#   Group 'Lager onderwijs' (n=771):
#     TP=172, FP=27, FN=52, TN=520
#     Precision: 0.864 | Recall: 0.768 | F1: 0.813
#     FPR: 0.049 | FNR: 0.232
#   Group 'Onbekend' (n=146):
#     TP=41, FP=12, FN=6, TN=87
#     Precision: 0.774 | Recall: 0.872 | F1: 0.820
#     FPR: 0.121 | FNR: 0.128
#
#  Fairness Analysis by: schoolse_vordering
#   Group 'Geen schoolse achterstand' (n=8940):
#     TP=20, FP=35, FN=123, TN=8762
#     Precision: 0.364 | Recall: 0.140 | F1: 0.202
#     FPR: 0.004 | FNR: 0.860
#   Group 'n.v.t.' (n=914):
#     TP=353, FP=258, FN=71, TN=232
#     Precision: 0.578 | Recall: 0.833 | F1: 0.682
#     FPR: 0.527 | FNR: 0.167
#   Group '1 jaar schoolse achterstand' (n=3186):
#     TP=475, FP=25, FN=183, TN=2503
#     Precision: 0.950 | Recall: 0.722 | F1: 0.820
#     FPR: 0.010 | FNR: 0.278
#   Group 'Meer dan 2 jaar schoolse achterstand' (n=307):
#     TP=168, FP=7, FN=22, TN=110
#     Precision: 0.960 | Recall: 0.884 | F1: 0.921
#     FPR: 0.060 | FNR: 0.116
#   Group '2 jaar schoolse achterstand' (n=987):
#     TP=404, FP=14, FN=71, TN=498
#     Precision: 0.967 | Recall: 0.851 | F1: 0.905
#     FPR: 0.027 | FNR: 0.149
#
# === Fairness Evaluation for: BiasMitigated_LogReg ===
#
#  Fairness Analysis by: geslacht
#   Group 'Vrouwelijk' (n=6900):
#     TP=553, FP=329, FN=137, TN=5881
#     Precision: 0.627 | Recall: 0.801 | F1: 0.704
#     FPR: 0.053 | FNR: 0.199
#   Group 'Mannelijk' (n=7434):
#     TP=1014, FP=634, FN=186, TN=5600
#     Precision: 0.615 | Recall: 0.845 | F1: 0.712
#     FPR: 0.102 | FNR: 0.155
#
#  Fairness Analysis by: belg_nietbelg
#   Group 'Belg' (n=13089):
#     TP=1196, FP=764, FN=281, TN=10848
#     Precision: 0.610 | Recall: 0.810 | F1: 0.696
#     FPR: 0.066 | FNR: 0.190
#   Group 'niet-Belg' (n=1245):
#     TP=371, FP=199, FN=42, TN=633
#     Precision: 0.651 | Recall: 0.898 | F1: 0.755
#     FPR: 0.239 | FNR: 0.102
#
#  Fairness Analysis by: eu_nieteu
#   Group 'EU' (n=13807):
#     TP=1363, FP=863, FN=304, TN=11277
#     Precision: 0.612 | Recall: 0.818 | F1: 0.700
#     FPR: 0.071 | FNR: 0.182
#   Group 'niet-EU' (n=527):
#     TP=204, FP=100, FN=19, TN=204
#     Precision: 0.671 | Recall: 0.915 | F1: 0.774
#     FPR: 0.329 | FNR: 0.085
#
#  Fairness Analysis by: woonplaats_provincie_naam
#   Group 'Vlaams-Brabant' (n=2205):
#     TP=192, FP=79, FN=45, TN=1889
#     Precision: 0.708 | Recall: 0.810 | F1: 0.756
#     FPR: 0.040 | FNR: 0.190
#   Group 'Oost-Vlaanderen' (n=3319):
#     TP=336, FP=190, FN=77, TN=2716
#     Precision: 0.639 | Recall: 0.814 | F1: 0.716
#     FPR: 0.065 | FNR: 0.186
#   Group 'West-Vlaanderen' (n=2365):
#     TP=197, FP=124, FN=52, TN=1992
#     Precision: 0.614 | Recall: 0.791 | F1: 0.691
#     FPR: 0.059 | FNR: 0.209
#   Group 'Antwerpen' (n=3955):
#     TP=556, FP=364, FN=89, TN=2946
#     Precision: 0.604 | Recall: 0.862 | F1: 0.711
#     FPR: 0.110 | FNR: 0.138
#   Group 'Limburg' (n=1810):
#     TP=192, FP=122, FN=46, TN=1450
#     Precision: 0.611 | Recall: 0.807 | F1: 0.696
#     FPR: 0.078 | FNR: 0.193
#   Group 'Brussels Hoofdstedelijk Gewest' (n=446):
#     TP=78, FP=70, FN=10, TN=288
#     Precision: 0.527 | Recall: 0.886 | F1: 0.661
#     FPR: 0.196 | FNR: 0.114
#   Group 'Buitenland + Waals Gewest' (n=234):
#     TP=16, FP=14, FN=4, TN=200
#     Precision: 0.533 | Recall: 0.800 | F1: 0.640
#     FPR: 0.065 | FNR: 0.200
#
#  Fairness Analysis by: leeftijdscategorie
#   Group '17-18' (n=9902):
#     TP=961, FP=202, FN=123, TN=8616
#     Precision: 0.826 | Recall: 0.887 | F1: 0.855
#     FPR: 0.023 | FNR: 0.113
#   Group '18-19' (n=3187):
#     TP=372, FP=378, FN=156, TN=2281
#     Precision: 0.496 | Recall: 0.705 | F1: 0.582
#     FPR: 0.142 | FNR: 0.295
#   Group '<17-18' (n=265):
#     TP=42, FP=4, FN=2, TN=217
#     Precision: 0.913 | Recall: 0.955 | F1: 0.933
#     FPR: 0.018 | FNR: 0.045
#   Group '20-21' (n=201):
#     TP=45, FP=125, FN=3, TN=28
#     Precision: 0.265 | Recall: 0.938 | F1: 0.413
#     FPR: 0.817 | FNR: 0.062
#   Group '19-20' (n=729):
#     TP=128, FP=231, FN=36, TN=334
#     Precision: 0.357 | Recall: 0.780 | F1: 0.489
#     FPR: 0.409 | FNR: 0.220
#   Group '21-22' (n=36):
#     TP=10, FP=19, FN=2, TN=5
#     Precision: 0.345 | Recall: 0.833 | F1: 0.488
#     FPR: 0.792 | FNR: 0.167
#   Group '>21-22' (n=14):
#     TP=9, FP=4, FN=1, TN=0
#     Precision: 0.692 | Recall: 0.900 | F1: 0.783
#     FPR: 1.000 | FNR: 0.100
#
#  Fairness Analysis by: opleidingsniveau_moeder
#   Group 'Hoger onderwijs' (n=6031):
#     TP=215, FP=67, FN=82, TN=5667
#     Precision: 0.762 | Recall: 0.724 | F1: 0.743
#     FPR: 0.012 | FNR: 0.276
#   Group 'Lager secundair onderwijs' (n=1699):
#     TP=351, FP=193, FN=44, TN=1111
#     Precision: 0.645 | Recall: 0.889 | F1: 0.748
#     FPR: 0.148 | FNR: 0.111
#   Group 'n.v.t.' (n=463):
#     TP=162, FP=217, FN=14, TN=70
#     Precision: 0.427 | Recall: 0.920 | F1: 0.584
#     FPR: 0.756 | FNR: 0.080
#   Group 'Hoger secundair onderwijs' (n=4628):
#     TP=432, FP=230, FN=129, TN=3837
#     Precision: 0.653 | Recall: 0.770 | F1: 0.706
#     FPR: 0.057 | FNR: 0.230
#   Group 'Geen lager onderwijs' (n=596):
#     TP=175, FP=127, FN=15, TN=279
#     Precision: 0.579 | Recall: 0.921 | F1: 0.711
#     FPR: 0.313 | FNR: 0.079
#   Group 'Lager onderwijs' (n=771):
#     TP=190, FP=101, FN=34, TN=446
#     Precision: 0.653 | Recall: 0.848 | F1: 0.738
#     FPR: 0.185 | FNR: 0.152
#   Group 'Onbekend' (n=146):
#     TP=42, FP=28, FN=5, TN=71
#     Precision: 0.600 | Recall: 0.894 | F1: 0.718
#     FPR: 0.283 | FNR: 0.106
#
#  Fairness Analysis by: schoolse_vordering
#   Group 'Geen schoolse achterstand' (n=8940):
#     TP=22, FP=13, FN=121, TN=8784
#     Precision: 0.629 | Recall: 0.154 | F1: 0.247
#     FPR: 0.001 | FNR: 0.846
#   Group 'n.v.t.' (n=914):
#     TP=410, FP=414, FN=14, TN=76
#     Precision: 0.498 | Recall: 0.967 | F1: 0.657
#     FPR: 0.845 | FNR: 0.033
#   Group '1 jaar schoolse achterstand' (n=3186):
#     TP=506, FP=257, FN=152, TN=2271
#     Precision: 0.663 | Recall: 0.769 | F1: 0.712
#     FPR: 0.102 | FNR: 0.231
#   Group 'Meer dan 2 jaar schoolse achterstand' (n=307):
#     TP=187, FP=97, FN=3, TN=20
#     Precision: 0.658 | Recall: 0.984 | F1: 0.789
#     FPR: 0.829 | FNR: 0.016
#   Group '2 jaar schoolse achterstand' (n=987):
#     TP=442, FP=182, FN=33, TN=330
#     Precision: 0.708 | Recall: 0.931 | F1: 0.804
#     FPR: 0.355 | FNR: 0.069
#
# === Fairness Evaluation for: BiasMitigated_XGBoost ===
#
#  Fairness Analysis by: geslacht
#   Group 'Vrouwelijk' (n=6900):
#     TP=519, FP=134, FN=171, TN=6076
#     Precision: 0.795 | Recall: 0.752 | F1: 0.773
#     FPR: 0.022 | FNR: 0.248
#   Group 'Mannelijk' (n=7434):
#     TP=951, FP=279, FN=249, TN=5955
#     Precision: 0.773 | Recall: 0.792 | F1: 0.783
#     FPR: 0.045 | FNR: 0.207
#
#  Fairness Analysis by: belg_nietbelg
#   Group 'Belg' (n=13089):
#     TP=1124, FP=314, FN=353, TN=11298
#     Precision: 0.782 | Recall: 0.761 | F1: 0.771
#     FPR: 0.027 | FNR: 0.239
#   Group 'niet-Belg' (n=1245):
#     TP=346, FP=99, FN=67, TN=733
#     Precision: 0.778 | Recall: 0.838 | F1: 0.807
#     FPR: 0.119 | FNR: 0.162
#
#  Fairness Analysis by: eu_nieteu
#   Group 'EU' (n=13807):
#     TP=1280, FP=361, FN=387, TN=11779
#     Precision: 0.780 | Recall: 0.768 | F1: 0.774
#     FPR: 0.030 | FNR: 0.232
#   Group 'niet-EU' (n=527):
#     TP=190, FP=52, FN=33, TN=252
#     Precision: 0.785 | Recall: 0.852 | F1: 0.817
#     FPR: 0.171 | FNR: 0.148
#
#  Fairness Analysis by: woonplaats_provincie_naam
#   Group 'Vlaams-Brabant' (n=2205):
#     TP=183, FP=30, FN=54, TN=1938
#     Precision: 0.859 | Recall: 0.772 | F1: 0.813
#     FPR: 0.015 | FNR: 0.228
#   Group 'Oost-Vlaanderen' (n=3319):
#     TP=318, FP=104, FN=95, TN=2802
#     Precision: 0.754 | Recall: 0.770 | F1: 0.762
#     FPR: 0.036 | FNR: 0.230
#   Group 'West-Vlaanderen' (n=2365):
#     TP=192, FP=70, FN=57, TN=2046
#     Precision: 0.733 | Recall: 0.771 | F1: 0.751
#     FPR: 0.033 | FNR: 0.229
#   Group 'Antwerpen' (n=3955):
#     TP=513, FP=137, FN=132, TN=3173
#     Precision: 0.789 | Recall: 0.795 | F1: 0.792
#     FPR: 0.041 | FNR: 0.205
#   Group 'Limburg' (n=1810):
#     TP=177, FP=49, FN=61, TN=1523
#     Precision: 0.783 | Recall: 0.744 | F1: 0.763
#     FPR: 0.031 | FNR: 0.256
#   Group 'Brussels Hoofdstedelijk Gewest' (n=446):
#     TP=72, FP=17, FN=16, TN=341
#     Precision: 0.809 | Recall: 0.818 | F1: 0.814
#     FPR: 0.047 | FNR: 0.182
#   Group 'Buitenland + Waals Gewest' (n=234):
#     TP=15, FP=6, FN=5, TN=208
#     Precision: 0.714 | Recall: 0.750 | F1: 0.732
#     FPR: 0.028 | FNR: 0.250
#
#  Fairness Analysis by: leeftijdscategorie
#   Group '17-18' (n=9902):
#     TP=944, FP=141, FN=140, TN=8677
#     Precision: 0.870 | Recall: 0.871 | F1: 0.870
#     FPR: 0.016 | FNR: 0.129
#   Group '18-19' (n=3187):
#     TP=339, FP=123, FN=189, TN=2536
#     Precision: 0.734 | Recall: 0.642 | F1: 0.685
#     FPR: 0.046 | FNR: 0.358
#   Group '<17-18' (n=265):
#     TP=41, FP=3, FN=3, TN=218
#     Precision: 0.932 | Recall: 0.932 | F1: 0.932
#     FPR: 0.014 | FNR: 0.068
#   Group '20-21' (n=201):
#     TP=34, FP=62, FN=14, TN=91
#     Precision: 0.354 | Recall: 0.708 | F1: 0.472
#     FPR: 0.405 | FNR: 0.292
#   Group '19-20' (n=729):
#     TP=96, FP=72, FN=68, TN=493
#     Precision: 0.571 | Recall: 0.585 | F1: 0.578
#     FPR: 0.127 | FNR: 0.415
#   Group '21-22' (n=36):
#     TP=6, FP=9, FN=6, TN=15
#     Precision: 0.400 | Recall: 0.500 | F1: 0.444
#     FPR: 0.375 | FNR: 0.500
#   Group '>21-22' (n=14):
#     TP=10, FP=3, FN=0, TN=1
#     Precision: 0.769 | Recall: 1.000 | F1: 0.870
#     FPR: 0.750 | FNR: 0.000
#
#  Fairness Analysis by: opleidingsniveau_moeder
#   Group 'Hoger onderwijs' (n=6031):
#     TP=213, FP=22, FN=84, TN=5712
#     Precision: 0.906 | Recall: 0.717 | F1: 0.801
#     FPR: 0.004 | FNR: 0.283
#   Group 'Lager secundair onderwijs' (n=1699):
#     TP=322, FP=72, FN=73, TN=1232
#     Precision: 0.817 | Recall: 0.815 | F1: 0.816
#     FPR: 0.055 | FNR: 0.185
#   Group 'n.v.t.' (n=463):
#     TP=149, FP=146, FN=27, TN=141
#     Precision: 0.505 | Recall: 0.847 | F1: 0.633
#     FPR: 0.509 | FNR: 0.153
#   Group 'Hoger secundair onderwijs' (n=4628):
#     TP=412, FP=90, FN=149, TN=3977
#     Precision: 0.821 | Recall: 0.734 | F1: 0.775
#     FPR: 0.022 | FNR: 0.266
#   Group 'Geen lager onderwijs' (n=596):
#     TP=160, FP=30, FN=30, TN=376
#     Precision: 0.842 | Recall: 0.842 | F1: 0.842
#     FPR: 0.074 | FNR: 0.158
#   Group 'Lager onderwijs' (n=771):
#     TP=174, FP=38, FN=50, TN=509
#     Precision: 0.821 | Recall: 0.777 | F1: 0.798
#     FPR: 0.069 | FNR: 0.223
#   Group 'Onbekend' (n=146):
#     TP=40, FP=15, FN=7, TN=84
#     Precision: 0.727 | Recall: 0.851 | F1: 0.784
#     FPR: 0.152 | FNR: 0.149
#
#  Fairness Analysis by: schoolse_vordering
#   Group 'Geen schoolse achterstand' (n=8940):
#     TP=18, FP=5, FN=125, TN=8792
#     Precision: 0.783 | Recall: 0.126 | F1: 0.217
#     FPR: 0.001 | FNR: 0.874
#   Group 'n.v.t.' (n=914):
#     TP=393, FP=335, FN=31, TN=155
#     Precision: 0.540 | Recall: 0.927 | F1: 0.682
#     FPR: 0.684 | FNR: 0.073
#   Group '1 jaar schoolse achterstand' (n=3186):
#     TP=475, FP=8, FN=183, TN=2520
#     Precision: 0.983 | Recall: 0.722 | F1: 0.833
#     FPR: 0.003 | FNR: 0.278
#   Group 'Meer dan 2 jaar schoolse achterstand' (n=307):
#     TP=175, FP=33, FN=15, TN=84
#     Precision: 0.841 | Recall: 0.921 | F1: 0.879
#     FPR: 0.282 | FNR: 0.079
#   Group '2 jaar schoolse achterstand' (n=987):
#     TP=409, FP=32, FN=66, TN=480
#     Precision: 0.927 | Recall: 0.861 | F1: 0.893
#     FPR: 0.062 | FNR: 0.139
